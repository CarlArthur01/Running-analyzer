# %%
import pandas as pd
import numpy as np
data = pd.read_csv('activities.csv')
data.shape

#check and compare: time of day, heart rate, pace, cadence, elevation gain, elevation loss, distance, duration
# Out:
# (192, 99)

# %%
data.columns=data.columns.str.lower()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 99 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   activity id                   192 non-null    int64
#  1   activity date                 192 non-null    object
#  2   activity name                 192 non-null    object
#  3   activity type                 192 non-null    object
#  4   activity description          28 non-null     object
#  5   elapsed time                  192 non-null    int64
#  6   distance                      192 non-null    float64
#  7   max heart rate                89 non-null     float64
#  8   relative effort               89 non-null     float64
#  9   commute                       192 non-null    bool
#  10  activity private note         0 non-null      float64
#  11  activity gear                 77 non-null     object
#  12  filename                      192 non-null    object
#  13  athlete weight                0 non-null      float64
#  14  bike weight                   0 non-null      float64
#  15  elapsed time.1                192 non-null    float64
#  16  moving time                   192 non-null    float64
#  17  distance.1                    192 non-null    float64
#  18  max speed                     192 non-null    float64
#  19  average speed                 192 non-null    float64
#  20  elevation gain                192 non-null    float64
#  21  elevation loss                192 non-null    float64
#  22  elevation low                 192 non-null    float64
#  23  elevation high                192 non-null    float64
#  24  max grade                     192 non-null    float64
#  25  average grade                 192 non-null    float64
#  26  average positive grade        0 non-null      float64
#  27  average negative grade        0 non-null      float64
#  28  max cadence                   86 non-null     float64
#  29  average cadence               86 non-null     float64
#  30  max heart rate.1              89 non-null     float64
#  31  average heart rate            89 non-null     float64
#  32  max watts                     0 non-null      float64
#  33  average watts                 42 non-null     float64
#  34  calories                      179 non-null    float64
#  35  max temperature               0 non-null      float64
#  36  average temperature           53 non-null     float64
#  37  relative effort.1             89 non-null     float64
#  38  total work                    42 non-null     float64
#  39  number of runs                0 non-null      float64
#  40  uphill time                   0 non-null      float64
#  41  downhill time                 0 non-null      float64
#  42  other time                    0 non-null      float64
#  43  perceived exertion            2 non-null      float64
#  44  type                          0 non-null      float64
#  45  start time                    0 non-null      float64
#  46  weighted average power        42 non-null     float64
#  47  power count                   42 non-null     float64
#  48  prefer perceived exertion     27 non-null     float64
#  49  perceived relative effort     2 non-null      float64
#  50  commute.1                     192 non-null    float64
#  51  total weight lifted           0 non-null      float64
#  52  from upload                   192 non-null    float64
#  53  grade adjusted distance       89 non-null     float64
#  54  weather observation time      91 non-null     float64
#  55  weather condition             91 non-null     float64
#  56  weather temperature           91 non-null     float64
#  57  apparent temperature          91 non-null     float64
#  58  dewpoint                      91 non-null     float64
#  59  humidity                      91 non-null     float64
#  60  weather pressure              91 non-null     float64
#  61  wind speed                    91 non-null     float64
#  62  wind gust                     91 non-null     float64
#  63  wind bearing                  91 non-null     float64
#  64  precipitation intensity       91 non-null     float64
#  65  sunrise time                  91 non-null     float64
#  66  sunset time                   91 non-null     float64
#  67  moon phase                    91 non-null     float64
#  68  bike                          0 non-null      float64
#  69  gear                          77 non-null     float64
#  70  precipitation probability     91 non-null     float64
#  71  precipitation type            91 non-null     float64
#  72  cloud cover                   91 non-null     float64
#  73  weather visibility            91 non-null     float64
#  74  uv index                      91 non-null     float64
#  75  weather ozone                 0 non-null      float64
#  76  jump count                    0 non-null      float64
#  77  total grit                    0 non-null      float64
#  78  average flow                  0 non-null      float64
#  79  flagged                       142 non-null    float64
#  80  average elapsed speed         192 non-null    float64
#  81  dirt distance                 192 non-null    float64
#  82  newly explored distance       0 non-null      float64
#  83  newly explored dirt distance  0 non-null      float64
#  84  activity count                0 non-null      float64
#  85  total steps                   88 non-null     float64
#  86  carbon saved                  52 non-null     float64
#  87  pool length                   0 non-null      float64
#  88  training load                 42 non-null     float64
#  89  intensity                     42 non-null     float64
#  90  average grade adjusted pace   78 non-null     float64
#  91  timer time                    0 non-null      float64
#  92  total cycles                  21 non-null     float64
#  93  recovery                      11 non-null     float64
#  94  with pet                      0 non-null      float64
#  95  competition                   0 non-null      float64
#  96  long run                      0 non-null      float64
#  97  for a cause                   0 non-null      float64
#  98  media                         24 non-null     object
# dtypes: bool(1), float64(89), int64(2), object(7)
# memory usage: 147.3+ KB

# %%
#select the relevant columns
print(data.iloc[:10:1])
# Out:
# Empty DataFrame
# Columns: [activity id, activity date, activity name, activity type, activity description, elapsed time, distance, max heart rate, relative effort, commute, activity private note, activity gear, filename, athlete weight, bike weight, elapsed time.1, moving time, distance.1, max speed, average speed, elevation gain, elevation loss, elevation low, elevation high, max grade, average grade, average positive grade, average negative grade, max cadence, average cadence, max heart rate.1, average heart rate, max watts, average watts, calories, max temperature, average temperature, relative effort.1, total work, number of runs, uphill time, downhill time, other time, perceived exertion, type, start time, weighted average power, power count, prefer perceived exertion, perceived relative effort, commute.1, total weight lifted, from upload, grade adjusted distance, weather observation time, weather condition, weather temperature, apparent temperature, dewpoint, humidity, weather pressure, wind speed, wind gust, wind bearing, precipitation intensity, sunrise time, sunset time, moon phase, bike, gear, precipitation probability, precipitation type, cloud cover, weather visibility, uv index, weather ozone, jump count, total grit, average flow, flagged, average elapsed speed, dirt distance, newly explored distance, newly explored dirt distance, activity count, total steps, carbon saved, pool length, training load, intensity, average grade adjusted pace, timer time, total cycles, recovery, with pet, competition, long run, for a cause, media]
# Index: []
#
# [0 rows x 99 columns]
